# %%
from sqlalchemy import create_engine
from config import db_password
import pandas as pd

# %%
db_string = f"postgres://postgres:{db_password}@indusscript.cljludlfcgoa.us-east-2.rds.amazonaws.com:5432/postgres"

# %%
engine = create_engine(db_string)

# %%
MLtest = pd.read_sql_table('MLtest', con=engine)
MLtest
# Out:
#     index  key letters prefix  vowel current prefix  \
# 0       0   40       வ   {""}      0           None
# 1       1   40       ள   {""}      0           None
# 2       2   40       ர   {""}      0           None
# 3       3   40       ்   {""}      0           None
# 4       4   40       ச   {""}      0           None
# 5       5   40       ்   {""}      0           None
# 6       6   40       ச   {""}      0           None
# 7       7   40       ி   {""}      1           None
# 8       8   40       ய   {""}      0           None
# 9       9   40       ை   {""}      1           None
# 10     10   40       க   {""}      0           None
# 11     11   40       ்   {""}      0           None
# 12     12   94       த   {""}      0           None
# 13     13   94       ம   {""}      0           None
# 14     14   94       ி   {""}      1           None
# 15     15   94       ழ   {""}      0           None
# 16     16   94       க   {""}      0           None
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# MLtest['letters_encoded'] = LabelEncoder().fit_transform(MLtest.letters)
# MLtest
# Out:
#     index  key letters prefix  vowel current prefix  \
# 0       0   40       வ   {""}      0           None
# 1       1   40       ள   {""}      0           None
# 2       2   40       ர   {""}      0           None
# 3       3   40       ்   {""}      0           None
# 4       4   40       ச   {""}      0           None
# 5       5   40       ்   {""}      0           None
# 6       6   40       ச   {""}      0           None
# 7       7   40       ி   {""}      1           None
# 8       8   40       ய   {""}      0           None
# 9       9   40       ை   {""}      1           None
# 10     10   40       க   {""}      0           None
# 11     11   40       ்   {""}      0           None
# 12     12   94       த   {""}      0           None
# 13     13   94       ம   {""}      0           None
# 14     14   94       ி   {""}      1           None
# 15     15   94       ழ   {""}      0           None
# 16     16   94       க   {""}      0           None
# ...

# %%
woe_df = MLtest

# %%
# Calculate probability of target = 1 i.e. Good = 1 for each category
woe_df = woe_df.groupby('letters').mean()
woe_df = pd.DataFrame(woe_df)
# Rename columns name
woe_df = woe_df.rename(columns = {'letters':'Good'})
woe_df['Good'] = 
# Calculate bad probability
woe_df['Bad'] = 1-woe_df.Good
# We need to add a small value to avoid divide by zero in denominator
woe_df['Bad'] = np.where(woe_df['Bad'] == 0, 0.000001, woe_df['Bad'])
# Compute the WoE
woe_df['WoE'] = np.log(woe_df.Good/woe_df.Bad)
woe_df
# Out:
#              index         key  vowel  morpheme boundary
# letters
# அ        21.000000  125.000000    0.0                0.0
# க        21.333333  116.666667    0.0                0.0
# ச        28.000000  206.200000    0.0                0.0
# ட        44.750000  308.000000    0.0                0.0
# த        34.750000  226.125000    0.0                0.0
# ப        27.000000  125.000000    0.0                0.0
# ம        13.000000   94.000000    0.0                0.0
# ய         8.000000   40.000000    0.0                0.0
# ர         2.000000   40.000000    0.0                0.0
# ற        22.000000  125.000000    0.0                0.0
# ள         1.000000   40.000000    0.0                0.0
# ழ        15.000000   94.000000    0.0                0.0
# வ        21.333333  148.666667    0.0                0.0
# ி        17.250000   96.000000    1.0                0.0
# ீ        41.000000  281.000000    1.0                0.0
# ...
