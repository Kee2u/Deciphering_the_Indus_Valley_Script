# %%
from sqlalchemy import create_engine
from config import db_password
import pandas as pd

# %%
db_string = f"postgres://postgres:{db_password}@indusscript.cljludlfcgoa.us-east-2.rds.amazonaws.com:5432/postgres"

# %%
engine = create_engine(db_string)

# %%
tamildata = pd.read_sql_table('completetamildata', con=engine)
tamildata
# Out:
#       index            form         lemma upos       xpos  head  \
# 0         0          சென்னை        சென்னை    N  NEN-3SN--     2
# 1         1           அருகே         அருகே    P  PP-------    18
# 2         2            ஸ்ரீ          ஸ்ரீ    N  NEN-3SN--     4
# 3         3  பெரும்புதூரில்  பெரும்புதூர்    N  NEL-3SN--    18
# 4         4          கிரீன்        கிரீன்    N  NEN-3SN--     6
# ...     ...             ...           ...  ...        ...   ...
# 9576   9576        வேண்டும்        வேண்டு    V  VR-F3SNAA     9
# 9577   9577          என்பது           என்    T  TQ-------    13
# 9578   9578            தான்          தான்    T  Tq-------    11
# 9579   9579             அது           அது    R  RpN-3SN--     0
# 9580   9580               .             .    Z  Z#-------     0
#
#      FormWithoutLemma  NoSpaceAfter  Counts                  formSeparated
# 0                               0.0       0                  {ச,ெ,ன,்,ன,ை}
# ...

# %%
wingdings = ['\u21E6','\u21E7','\u21E8','\u21E9','\u21F3','\u237D','\u2303','\u237D','\u2303','\u2316','\u2324','\u2325',
             '\u2326','\u2327', '\u232B','\u232D','\u238B','\u23F3','\u2423','\u24C5','\u24FF','\u261C','\u261E','\u261D','\u261F','\u25A0','\u25A1','\u2620','\u262F','\u2639','\u263A','\u263C','\u267F','\u26F7','\u2701','\u2702','\u2706','\u2707','\u2708','\u270C','\u270D','\u2744','\u2B00','\u2B01','\u2B02','\u2B03','\u2B04','\u2318','\u2327','\u25C6','\u2605','\u2726','\u2734','\u2735','\u2736','\u2739','\u2756','\u2BD0','\u2BD1','\u272A','\u2730','\u2714']

# %% [markdown]
# # Morpheme

# %%
morphemelist = pd.read_sql_table('morphemes', con=engine)
morphemelist
# Out:
#     index MorphemeSeparated Morpheme   xpos Regex  Morpheme continued
# 0       2                 ை        ை  (N.A..S...)                 NaN
# 1       3         {க,்,க,்}     க்க்  (N.D..S...)                 1.0
# 2       4         {க,்,க,ு}     க்கு  (N.D..S...)                 NaN
# 3       5             {க,ு}       கு  (N.D..S...)                 NaN
# 4       6           {க,ள,ு}      களு  (N.D..P...)                 NaN
# ..    ...               ...      ...          ...                 ...
# 92     94               {ை}        ை  (V.A......)                 NaN
# 93     95             {க,ு}       கு  (V.D......)                 NaN
# 94     96             {க,்}       க்  (V.D......)                 1.0
# 95     97           {ா,ல,்}      ால்  (V.I......)                 NaN
# 96     98           {ி,ல,்}      ில்  (V.L......)                 NaN
#
# [97 rows x 5 columns]

# %%
morphemelist['Morpheme'].nunique()
# Out:
# 54

# %%
morphemetowingdings = morphemelist['Morpheme'].unique()
morphemetowingdings
# Out:
# array(['ை', 'க்க்', 'க்கு', 'கு', 'களு', 'ால்', 'து', 'ின்', 'ில்',
#        'ிடம்', 'ோடு', 'ுடன்', 'கள்', 'ேன்', 'கிற', 'ணட', 'க்கிற', 'ன',
#        'ீர்கள்', 'ந்த', 'ிய', 'த்த', '்ட', 'த', 'ட்ட', 'க்க', 'க', 'ும்',
#        'ா', 'ார்', 'ின', 'வ', 'ோம்', 'ப்ப', 'ர்', 'க்கின்ற', 'ார்கள்',
#        'ி', 'கின்ற', 'டு', 'ந்து', 'த்து', 'ட்', 'த்', 'ட்டு', 'ணடு',
#        'ணட்', 'ந்த்', 'த்த்', 'ட்ட்', 'வர', 'கள', 'ப', 'க்'], dtype=object)

# %%
morphemelist['xpos Regex'].nunique()
# Out:
# 31

# %%
morphemelist['xpos Regex'].unique()
# Out:
# array(['(N.A..S...)', '(N.D..S...)', '(N.D..P...)', '(N.I......)',
#        '(N.G.*)', '(N.L.*)', '(N.S.*)', '(N....P...)', '(V...1S...)',
#        '(V...2S...)', '(V.-D3SN.)', '(V..P3SN.)', '(V.-F3SN.)',
#        '(V.-T3SN.)', '(V.......N)', '(V...3SH.)', '(V...1P..)',
#        '(V...2P..)', '(V..D3PH.)', '(V..P3PH.)', '(V..F3PH.)',
#        '(V..T3PH.)', '(V..D3PN.)', '(V..P3PN.)', '(VT.......)',
#        '(VW.......)', '(NP.......)', '(V.A......)', '(V.D......)',
#        '(V.I......)', '(V.L......)'], dtype=object)

# %%
morphemelist[['xpos Regex']]
# Out:
#      xpos Regex
# 0   (N.A..S...)
# 1   (N.D..S...)
# 2   (N.D..S...)
# 3   (N.D..S...)
# 4   (N.D..P...)
# ..          ...
# 92  (V.A......)
# 93  (V.D......)
# 94  (V.D......)
# 95  (V.I......)
# 96  (V.L......)
#
# [97 rows x 1 columns]

# %%
# wingdings = 
# ['\u21E6','\u21E7','\u21E8','\u21E9','\u21F3',
 
#  '\u237D','\u2303','\u237D','\u2303','\u2316','\u2324','\u2325',
#  '\u2318','\u2327','\u2326','\u2327', '\u232B','\u232D','\u238B','\u23F3',
 
#  '\u2423','\u24C5','\u24FF',

#  '\u25A0','\u25A1', '\u25C6,'
 
#  '\u261C','\u261E','\u261D','\u261F','\u2620','\u262F','\u2639','\u263A',
#  '\u263C','\u267F','\u26F7','\u2605',

#  '\u2701','\u2702','\u2706','\u2707','\u2708','\u270C','\u270D','\u2744',
#  '\u2726','\u2734','\u2735','\u2736','\u2739','\u2756','\u272A','\u2730',
#  '\u2714'

#  '\u2B00','\u2B01','\u2B02','\u2B03','\u2B04',
# '\u2BD0','\u2BD1']
# len(wingdings)

# %%
morphemes_df = pd.DataFrame(morphemetowingdings,columns=['Morphemes'])
morphemes_df
# Out:
#    Morphemes
# 0          ை
# 1       க்க்
# 2       க்கு
# 3         கு
# 4        களு
# 5        ால்
# 6         து
# 7        ின்
# 8        ில்
# 9       ிடம்
# 10       ோடு
# 11      ுடன்
# 12       கள்
# 13       ேன்
# 14       கிற
# 15        ணட
# 16     க்கிற
# 17         ன
# 18    ீர்கள்
# 19       ந்த
# 20        ிய
# 21       த்த
# 22        ்ட
# 23         த
# 24       ட்ட
# 25       க்க
# 26         க
# 27       ும்
# 28         ா
# 29       ார்
# 30        ின
# 31         வ
# 32       ோம்
# 33       ப்ப
# 34        ர்
# 35   க்கின்ற
# 36    ார்கள்
# 37         ி
# 38     கின்ற
# 39        டு
# 40      ந்து
# 41      த்து
# 42        ட்
# 43        த்
# 44      ட்டு
# 45       ணடு
# 46       ணட்
# 47      ந்த்
# 48      த்த்
# 49      ட்ட்
# 50        வர
# 51        கள
# 52         ப
# 53        க்

# %%
#wingdings list for morphemes
wingdings2 = ['\u2638', '\u2648', '\u2649',  '\u264A', '\u264B', '\u264C', '\u264D', '\u264E', '\u264F', '\u2650', '\u2651', '\u2652', '\u2653', '\u2751', '\u2752', '\u2B27', '\u29EB', '\u2B25', '\u2BB9', '\u25C9', '\u25CE', '\u2BB0', '\u2BB1', '\u2BB2', '\u2BB3', '\u2BB4', '\u2BB5', '\u2BB6', '\u2BB7', '\u2B98', '\u2B9A', '\u2B99', '\u2B9B', '\u2B88', '\u2B8A', '\u2B89', '\u2B8B', '\u25AA', '\u26AA', '\u25FB', '\u27E1', '\u2311', '\u2BD1', '\u24EA', '\u2460', '\u2461', '\u2462', '\u2463', '\u2464', '\u2465', '\u2466', '\u2467', '\u2468', '\u2469', '\u24FF', '\u2776', '\u2777', '\u2778', '\u2779', '\u277A', '\u277B', '\u277C', '\u277D', '\u277E', '\u277F']
len(wingdings2)
# Out:
# 65

# %%
wingdings_df = pd.DataFrame(wingdings2,columns=['Wingdings'])
wingdings_df
# Out:
#    Wingdings
# 0          ☸
# 1          ♈
# 2          ♉
# 3          ♊
# 4          ♋
# ..       ...
# 60         ❻
# 61         ❼
# 62         ❽
# 63         ❾
# 64         ❿
#
# [65 rows x 1 columns]

# %%
columns = ['Morphemes','Wingdings']
morphemes_logo = pd.DataFrame(columns = columns)
morphemes_logo['Morphemes'] = morphemes_df['Morphemes']
morphemes_logo['Wingdings'] = wingdings_df['Wingdings']
morphemes_logo
# Out:
#    Morphemes Wingdings
# 0          ை         ☸
# 1       க்க்         ♈
# 2       க்கு         ♉
# 3         கு         ♊
# 4        களு         ♋
# 5        ால்         ♌
# 6         து         ♍
# 7        ின்         ♎
# 8        ில்         ♏
# 9       ிடம்         ♐
# 10       ோடு         ♑
# 11      ுடன்         ♒
# 12       கள்         ♓
# 13       ேன்         ❑
# 14       கிற         ❒
# 15        ணட         ⬧
# 16     க்கிற         ⧫
# 17         ன         ⬥
# 18    ீர்கள்         ⮹
# 19       ந்த         ◉
# 20        ிய         ◎
# 21       த்த         ⮰
# 22        ்ட         ⮱
# 23         த         ⮲
# 24       ட்ட         ⮳
# 25       க்க         ⮴
# 26         க         ⮵
# 27       ும்         ⮶
# 28         ா         ⮷
# 29       ார்         ⮘
# 30        ின         ⮚
# 31         வ         ⮙
# 32       ோம்         ⮛
# 33       ப்ப         ⮈
# 34        ர்         ⮊
# 35   க்கின்ற         ⮉
# 36    ார்கள்         ⮋
# 37         ி         ▪
# 38     கின்ற         ⚪
# ...

# %%
# Create function (takes in array of words and replaces with converted wingdings array)
# Case: morpheme = form
def morpheme_to_wingding(input):
    morpheme = morpheme_logo['Morphemes']
    logo = morpheme_logo['Wingdings']
    # for every word in array, compare to clitics_logo
    for j in range(len(input)):
        for i in range(len(morpheme_logo)):
            if input[j] == morpheme[i]:
                input[j] = logo[i];
    return input

# %%
# Example Case: morpheme = end of form
# E.g. Noun Accusative Singular Case
#re = '(N.A..S...)'
#morphemelist[morphemelist['xpos Regex'].str.contains(rf'{re}')]
# if form = 'தமிழகத்தை' and morpheme = 'ததை'
count = 0
for j in range(len(morpheme)):
    if word[-j] == morpheme[-j]:
        count++;
if count = len(morpheme):
    word = morpheme
# Out:
#    index MorphemeSeparated Morpheme   xpos Regex  Morpheme continued
# 0      2                 ை        ை  (N.A..S...)                 NaN
